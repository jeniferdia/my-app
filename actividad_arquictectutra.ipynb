# %% [markdown]
# <a href="https://colab.research.google.com/github/jeniferdia/my-app/blob/main/actividad_arquictectutra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1)presentacion
# 2)exporacion
# 3)eliminacion
# 4)normalizacion
# 5)correccion de datos
# 6)exportacion

# %% [markdown]
# # 1)preparacion de de datos

# %% [markdown]
# importamos librerias a necesitar

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# leer el achivo original

# %%
df = pd.read_csv('Desembolsos_de_Crédito_de_Fomento_Agropecuario_-_GUATICA_20260422.csv')

# %% [markdown]
# mostrar las dimenciones de la base original

# %%
df.shape
# Out:
# (3369, 27)

# %% [markdown]
# indentificacion de datos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3369 entries, 0 to 3368
# Data columns (total 27 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id_credito                    3369 non-null   object
#  1   fecha_credito                 3369 non-null   object
#  2   cod_municipio                 3369 non-null   object
#  3   tipo_cartera                  3369 non-null   object
#  4   tipo_intermediario            3369 non-null   object
#  5   tipo_productor                3369 non-null   object
#  6   tipo_beneficiario             3369 non-null   object
#  7   tipo_persona                  3369 non-null   object
#  8   sexo                          3309 non-null   object
#  9   cod_destino                   3369 non-null   object
#  10  linea_credito                 3369 non-null   object
#  11  cadena                        3369 non-null   object
#  12  eslabon_cadena                3369 non-null   object
#  13  valor_credito                 3369 non-null   object
#  14  valor_inversion               3369 non-null   object
#  15  plazo                         3369 non-null   int64
#  16  periodo_gracia                3369 non-null   int64
#  17  cuotas                        3369 non-null   int64
#  18  cuotas_capital                3369 non-null   int64
#  19  tasa_indexacion               3369 non-null   object
#  20  periodicidad_tasa_indexacion  3050 non-null   object
#  21  puntos_adicionales            3369 non-null   float64
#  22  garantia_fag                  3369 non-null   int64
#  23  nombre_programa               3369 non-null   object
#  24  indicador_lec                 3369 non-null   int64
#  25  valor_subsidio                3369 non-null   object
#  26  nuevo                         3369 non-null   int64
# dtypes: float64(1), int64(7), object(19)
# memory usage: 710.8+ KB

# %% [markdown]
# #2)exploracion de datos

# %% [markdown]
#  revisión de datos

# %%
df
# Out:
#          id_credito            fecha_credito cod_municipio tipo_cartera  \
# 0     2,050,369,482  2020 Aug 06 12:00:00 AM        66,318  Redescuento
# 1     2,350,433,520  2023 Nov 09 12:00:00 AM        66,318  Redescuento
# 2     2,350,169,580  2023 Mar 09 12:00:00 AM        66,318  Redescuento
# 3     2,350,467,737  2023 Dec 14 12:00:00 AM        66,318  Redescuento
# 4     2,350,474,927  2023 Dec 20 12:00:00 AM        66,318  Redescuento
# ...             ...                      ...           ...          ...
# 3364  2,650,149,763  2026 Feb 25 12:00:00 AM        66,318  Redescuento
# 3365  2,603,065,993  2026 Jan 02 12:00:00 AM        66,318  Sustitutiva
# 3366  2,603,098,860  2026 Mar 10 12:00:00 AM        66,318  Redescuento
# 3367  2,603,095,861  2026 Mar 02 12:00:00 AM        66,318  Sustitutiva
# 3368  2,603,105,533  2026 Mar 25 12:00:00 AM        66,318  Sustitutiva
#
#      tipo_intermediario tipo_productor                    tipo_beneficiario  \
# 0                Bancos        Pequeño                    Pequeño productor
# 1                Bancos   Pequeño ppib                      Desplazado ppib
# 2                Bancos   Pequeño ppib                     Mujer rural ppib
# 3                Bancos   Pequeño ppib  Pequeño productor de ingresos bajos
# 4                Bancos   Pequeño ppib  Pequeño productor de ingresos bajos
# ...                 ...            ...                                  ...
# 3364             Bancos   Pequeño ppib  Pequeño productor de ingresos bajos
# 3365             Bancos   Pequeño ppib  Pequeño productor de ingresos bajos
# 3366             Bancos      No aplica                        Mipymes rural
# 3367             Bancos   Pequeño ppib  Pequeño productor de ingresos bajos
# 3368             Bancos      No aplica                        Mipymes rural
#
#      tipo_persona    sexo cod_destino  ... cuotas cuotas_capital  \
# 0         Natural  Hombre     160,000  ...      6              6
# 1         Natural  Hombre     141,101  ...     12              5
# 2         Natural   Mujer     641,050  ...     10             10
# 3         Natural   Mujer     160,000  ...      3              3
# 4         Natural  Hombre     160,000  ...      6              6
# ...           ...     ...         ...  ...    ...            ...
# 3364      Natural  Hombre     160,000  ...      6              6
# 3365      Natural  Hombre     132,310  ...     12              1
# 3366      Natural  Hombre     160,000  ...     24              1
# 3367      Natural  Hombre     132,310  ...     12              1
# 3368      Natural  Hombre     160,000  ...     24             24
#
#      tasa_indexacion periodicidad_tasa_indexacion puntos_adicionales  \
# 0                IBR                    Semestral                6.7
# 1                IBR                    Semestral                1.9
# 2                IBR                    Semestral                3.8
# 3                IBR                    Semestral                2.6
# 4                IBR                    Semestral                2.6
# ...              ...                          ...                ...
# 3364             IBR                    Semestral                6.5
# 3365             IBR                      Mensual                5.7
# 3366             IBR                      Mensual               62.4
# 3367             IBR                      Mensual                6.7
# 3368             IBR                      Mensual               71.6
#
#       garantia_fag                                    nombre_programa  \
# 0                1                              IBR CREDITO ORDINARIO
# 1                1  IBR FINANCIACIÓN PROYECTOS EJECUTADOS POBLACIÓ...
# 2                1                              IBR CREDITO ORDINARIO
# 3                1                              IBR CREDITO ORDINARIO
# 4                1                              IBR CREDITO ORDINARIO
# ...            ...                                                ...
# 3364             0                              IBR CREDITO ORDINARIO
# 3365             0                           IBR TARJETA AGROPECUARIA
# 3366             0  1987 IBR MICROCREDITO GLOBAL POPULAR PRODUCTIV...
# 3367             0                           IBR TARJETA AGROPECUARIA
# 3368             0    1973 IBR MICROCREDITO POPULAR PRODUCTIVO URBANO
#
#       indicador_lec  valor_subsidio nuevo
# 0                 0               0     0
# 1                 0               0     0
# 2                 0               0     0
# 3                 0               0     0
# 4                 0               0     0
# ...             ...             ...   ...
# 3364              0               0     0
# 3365              0               0     0
# 3366              0               0     0
# 3367              0               0     0
# 3368              0               0     0
#
# [3369 rows x 27 columns]

# %% [markdown]
# analisis de los primeros 20 datos

# %%
df.head(20)
# Out:
#        id_credito            fecha_credito cod_municipio tipo_cartera  \
# 0   2,050,369,482  2020 Aug 06 12:00:00 AM        66,318  Redescuento
# 1   2,350,433,520  2023 Nov 09 12:00:00 AM        66,318  Redescuento
# 2   2,350,169,580  2023 Mar 09 12:00:00 AM        66,318  Redescuento
# 3   2,350,467,737  2023 Dec 14 12:00:00 AM        66,318  Redescuento
# 4   2,350,474,927  2023 Dec 20 12:00:00 AM        66,318  Redescuento
# 5   2,102,211,228  2021 Jul 21 12:00:00 AM        66,318  Sustitutiva
# 6   2,450,321,133  2024 Aug 23 12:00:00 AM        66,318  Redescuento
# 7   2,502,929,558  2025 Feb 03 12:00:00 AM        66,318  Sustitutiva
# 8   2,450,312,524  2024 Aug 13 12:00:00 AM        66,318  Redescuento
# 9   2,250,227,219  2022 Feb 03 12:00:00 AM        66,318  Redescuento
# 10  2,450,288,716  2024 Jul 22 12:00:00 AM        66,318  Redescuento
# 11  2,450,433,540  2024 Dec 24 12:00:00 AM        66,318  Redescuento
# 12  2,302,609,050  2023 Jun 02 12:00:00 AM        66,318  Sustitutiva
# 13  2,150,276,768  2021 Mar 30 12:00:00 AM        66,318  Redescuento
# 14  2,250,367,996  2022 Jun 23 12:00:00 AM        66,318  Redescuento
# 15  2,050,296,549  2020 May 18 12:00:00 AM        66,318  Redescuento
# 16  2,350,467,345  2023 Dec 14 12:00:00 AM        66,318  Redescuento
# 17  2,150,267,796  2021 Mar 18 12:00:00 AM        66,318  Redescuento
# 18  2,350,418,881  2023 Oct 25 12:00:00 AM        66,318  Redescuento
# 19  2,050,398,882  2020 Aug 28 12:00:00 AM        66,318  Redescuento
#
#    tipo_intermediario tipo_productor                    tipo_beneficiario  \
# 0              Bancos        Pequeño                    Pequeño productor
# 1              Bancos   Pequeño ppib                      Desplazado ppib
# 2              Bancos   Pequeño ppib                     Mujer rural ppib
# 3              Bancos   Pequeño ppib  Pequeño productor de ingresos bajos
# 4              Bancos   Pequeño ppib  Pequeño productor de ingresos bajos
# 5              Bancos        Pequeño                    Pequeño productor
# 6              Bancos   Pequeño ppib  Pequeño productor de ingresos bajos
# 7              Bancos        Pequeño                    Pequeño productor
# 8              Bancos   Pequeño ppib  Pequeño productor de ingresos bajos
# 9              Bancos        Pequeño                    Pequeño productor
# 10             Bancos   Pequeño ppib  Pequeño productor de ingresos bajos
# 11             Bancos   Pequeño ppib  Pequeño productor de ingresos bajos
# 12             Bancos        Pequeño              Microempresario pequeño
# 13             Bancos        Pequeño                      Desplazados p.p
# 14             Bancos        Pequeño                      Desplazados p.p
# 15             Bancos        Pequeño                      Desplazados p.p
# 16             Bancos   Pequeño ppib  Pequeño productor de ingresos bajos
# 17             Bancos        Pequeño                    Pequeño productor
# 18             Bancos   Pequeño ppib  Pequeño productor de ingresos bajos
# 19             Bancos        Pequeño                    Pequeño productor
#
#    tipo_persona    sexo cod_destino  ... cuotas cuotas_capital  \
# 0       Natural  Hombre     160,000  ...      6              6
# 1       Natural  Hombre     141,101  ...     12              5
# 2       Natural   Mujer     641,050  ...     10             10
# 3       Natural   Mujer     160,000  ...      3              3
# 4       Natural  Hombre     160,000  ...      6              6
# 5       Natural  Hombre     132,310  ...     12              1
# 6       Natural  Hombre     141,525  ...      8              3
# 7       Natural  Hombre     132,310  ...     12              1
# 8       Natural  Hombre     132,040  ...      6              6
# 9       Natural  Hombre     151,360  ...      6              4
# 10      Natural  Hombre     160,000  ...      3              3
# 11      Natural   Mujer     132,040  ...      6              6
# 12      Natural  Hombre     165,000  ...     18             18
# 13      Natural  Hombre     160,000  ...      6              6
# 14      Natural   Mujer     132,310  ...      1              1
# 15      Natural  Hombre     141,430  ...     10              8
# 16      Natural  Hombre     132,040  ...      4              4
# 17      Natural   Mujer     841,100  ...     14             12
# 18      Natural  Hombre     841,100  ...     10             10
# 19      Natural  Hombre     253,400  ...      8              8
#
#    tasa_indexacion periodicidad_tasa_indexacion puntos_adicionales  \
# 0              IBR                    Semestral              6.700
# 1              IBR                    Semestral              1.900
# 2              IBR                    Semestral              3.800
# 3              IBR                    Semestral              2.600
# 4              IBR                    Semestral              2.600
# 5              IBR                      Mensual              6.700
# 6              IBR                    Semestral              6.700
# 7              IBR                      Mensual              4.000
# 8              IBR                    Semestral             -2.200
# 9              IBR                    Semestral              6.700
# 10             IBR                    Semestral              6.500
# 11             IBR                    Semestral              6.700
# 12             IBR                      Mensual             40.506
# 13             IBR                    Semestral              1.900
# 14             IBR                    Semestral              0.000
# 15             IBR                    Semestral              1.900
# 16             IBR                    Semestral             -7.000
# 17             IBR                    Semestral              6.700
# 18             IBR                    Semestral              2.700
# 19             DTF                          NaN              7.000
#
#     garantia_fag                                    nombre_programa  \
# 0              1                              IBR CREDITO ORDINARIO
# 1              1  IBR FINANCIACIÓN PROYECTOS EJECUTADOS POBLACIÓ...
# 2              1                              IBR CREDITO ORDINARIO
# 3              1                              IBR CREDITO ORDINARIO
# 4              1                              IBR CREDITO ORDINARIO
# 5              0                           IBR TARJETA AGROPECUARIA
# 6              1                              IBR CREDITO ORDINARIO
# 7              0                           IBR TARJETA AGROPECUARIA
# 8              1              IBR LEC 2024 DESARROLLO PRODUCTIVO N2
# 9              1                              IBR CREDITO ORDINARIO
# 10             1                              IBR CREDITO ORDINARIO
# 11             1                              IBR CREDITO ORDINARIO
# 12             0              IBR MICROCREDITO AGROPECUARIO Y RURAL
# 13             1  IBR FINANCIACIÓN PROYECTOS EJECUTADOS POBLACIÓ...
# 14             1                         IBR LEC 2022 PARA VICTIMAS
# 15             1  IBR FINANCIACIÓN PROYECTOS EJECUTADOS POBLACIÓ...
# 16             1                 IBR LEC 2023 DESARROLLO PRODUCTIVO
# 17             1                              IBR CREDITO ORDINARIO
# 18             1                              IBR CREDITO ORDINARIO
# 19             1                     REESTRUCTURACIÓN CUOTA VENCIDA
#
#     indicador_lec  valor_subsidio nuevo
# 0               0               0     0
# 1               0               0     0
# 2               0               0     0
# 3               0               0     0
# 4               0               0     0
# 5               0               0     0
# 6               0               0     0
# 7               0               0     0
# 8               1         457,841     0
# 9               0               0     0
# 10              0               0     0
# 11              0               0     0
# 12              0               0     1
# 13              0               0     1
# 14              1          62,757     0
# 15              0               0     0
# 16              1         289,628     0
# 17              0               0     1
# 18              0               0     0
# 19              0               0     0
#
# [20 rows x 27 columns]

# %% [markdown]
# analisis de las ultimos 20 datos

# %%
df.tail(20)
# Out:
#          id_credito            fecha_credito cod_municipio tipo_cartera  \
# 3349  2,650,113,114  2026 Jan 20 12:00:00 AM        66,318  Redescuento
# 3350  2,603,077,553  2026 Feb 02 12:00:00 AM        66,318  Sustitutiva
# 3351  2,650,101,902  2026 Jan 07 12:00:00 AM        66,318  Redescuento
# 3352  2,603,098,919  2026 Mar 10 12:00:00 AM        66,318  Redescuento
# 3353  2,650,154,878  2026 Mar 02 12:00:00 AM        66,318  Redescuento
# 3354  2,650,176,040  2026 Mar 24 12:00:00 AM        66,318  Redescuento
# 3355  2,603,087,478  2026 Feb 18 12:00:00 AM        66,318  Sustitutiva
# 3356  2,603,075,565  2026 Jan 30 12:00:00 AM        66,318  Sustitutiva
# 3357  2,650,113,094  2026 Jan 20 12:00:00 AM        66,318  Redescuento
# 3358  2,650,106,555  2026 Jan 13 12:00:00 AM        66,318  Redescuento
# 3359  2,603,094,109  2026 Mar 02 12:00:00 AM        66,318  Sustitutiva
# 3360  2,650,147,716  2026 Feb 24 12:00:00 AM        66,318  Redescuento
# 3361  2,650,101,281  2026 Jan 06 12:00:00 AM        66,318  Redescuento
# 3362  2,650,180,220  2026 Mar 27 12:00:00 AM        66,318  Redescuento
# 3363  2,650,113,389  2026 Jan 20 12:00:00 AM        66,318  Redescuento
# 3364  2,650,149,763  2026 Feb 25 12:00:00 AM        66,318  Redescuento
# 3365  2,603,065,993  2026 Jan 02 12:00:00 AM        66,318  Sustitutiva
# 3366  2,603,098,860  2026 Mar 10 12:00:00 AM        66,318  Redescuento
# 3367  2,603,095,861  2026 Mar 02 12:00:00 AM        66,318  Sustitutiva
# 3368  2,603,105,533  2026 Mar 25 12:00:00 AM        66,318  Sustitutiva
#
#      tipo_intermediario tipo_productor                    tipo_beneficiario  \
# 3349             Bancos        Pequeño                      Desplazados p.p
# 3350             Bancos        Pequeño                    Pequeño productor
# 3351             Bancos   Pequeño ppib                      Desplazado ppib
# 3352             Bancos      No aplica                        Mipymes rural
# 3353             Bancos   Pequeño ppib  Pequeño productor de ingresos bajos
# 3354             Bancos   Pequeño ppib  Pequeño productor de ingresos bajos
# 3355             Bancos      No aplica                        Mipymes rural
# 3356             Bancos   Pequeño ppib  Pequeño productor de ingresos bajos
# 3357             Bancos        Pequeño                    Pequeño productor
# 3358             Bancos        Pequeño                      Desplazados p.p
# 3359             Bancos        Pequeño                    Pequeño productor
# 3360             Bancos   Pequeño ppib  Pequeño productor de ingresos bajos
# 3361             Bancos   Pequeño ppib  Pequeño productor de ingresos bajos
# 3362             Bancos   Pequeño ppib  Pequeño productor de ingresos bajos
# 3363             Bancos   Pequeño ppib  Pequeño productor de ingresos bajos
# 3364             Bancos   Pequeño ppib  Pequeño productor de ingresos bajos
# 3365             Bancos   Pequeño ppib  Pequeño productor de ingresos bajos
# 3366             Bancos      No aplica                        Mipymes rural
# 3367             Bancos   Pequeño ppib  Pequeño productor de ingresos bajos
# 3368             Bancos      No aplica                        Mipymes rural
#
#      tipo_persona    sexo cod_destino  ... cuotas cuotas_capital  \
# 3349      Natural   Mujer     141,100  ...      8              4
# 3350      Natural  Hombre     132,310  ...     12              1
# 3351      Natural  Hombre     141,101  ...      8              4
# 3352      Natural   Mujer     160,000  ...     12              1
# 3353      Natural  Hombre     160,000  ...      3              3
# 3354      Natural  Hombre     133,010  ...      2              2
# 3355      Natural  Hombre     160,000  ...      4              4
# 3356      Natural  Hombre     641,160  ...     60             60
# 3357      Natural  Hombre     151,310  ...      4              2
# 3358      Natural  Hombre     141,100  ...      6              3
# 3359      Natural  Hombre     132,310  ...     12              1
# 3360      Natural  Hombre     160,000  ...      6              6
# 3361      Natural   Mujer     160,000  ...      6              6
# 3362      Natural   Mujer     160,000  ...      6              6
# 3363      Natural   Mujer     160,000  ...      3              3
# 3364      Natural  Hombre     160,000  ...      6              6
# 3365      Natural  Hombre     132,310  ...     12              1
# 3366      Natural  Hombre     160,000  ...     24              1
# 3367      Natural  Hombre     132,310  ...     12              1
# 3368      Natural  Hombre     160,000  ...     24             24
#
#      tasa_indexacion periodicidad_tasa_indexacion puntos_adicionales  \
# 3349             IBR                    Semestral                1.9
# 3350             IBR                      Mensual                5.7
# 3351             IBR                    Semestral                1.9
# 3352             IBR                      Mensual               64.2
# 3353             IBR                    Semestral                6.5
# 3354             IBR                    Semestral                6.7
# 3355             IBR                    Semestral               52.0
# 3356             IBR                      Mensual                6.7
# 3357             DTF                    No aplica                7.0
# 3358             IBR                    Semestral                1.9
# 3359             IBR                      Mensual                6.7
# 3360             IBR                    Semestral                6.5
# 3361             IBR                    Semestral                6.5
# 3362             IBR                    Semestral                6.5
# 3363             IBR                    Semestral                6.5
# 3364             IBR                    Semestral                6.5
# 3365             IBR                      Mensual                5.7
# 3366             IBR                      Mensual               62.4
# 3367             IBR                      Mensual                6.7
# 3368             IBR                      Mensual               71.6
#
#       garantia_fag                                    nombre_programa  \
# 3349             0  IBR REES CTA VEN FINANC DE PROY EJECUTADOS POR...
# 3350             0                           IBR TARJETA AGROPECUARIA
# 3351             0  IBR REES CTA VEN FINANC DE PROY EJECUTADOS POR...
# 3352             0  1987 IBR MICROCREDITO GLOBAL POPULAR PRODUCTIV...
# 3353             0                              IBR CREDITO ORDINARIO
# 3354             0                 IBR REESTRUCTURACION CUOTA VENCIDA
# 3355             0    1973 IBR MICROCREDITO POPULAR PRODUCTIVO URBANO
# 3356             0                              IBR CREDITO ORDINARIO
# 3357             0                     REESTRUCTURACIÓN CUOTA VENCIDA
# 3358             0  IBR REES CTA VEN FINANC DE PROY EJECUTADOS POR...
# 3359             0                           IBR TARJETA AGROPECUARIA
# 3360             0                              IBR CREDITO ORDINARIO
# 3361             0                              IBR CREDITO ORDINARIO
# 3362             0                              IBR CREDITO ORDINARIO
# 3363             0                              IBR CREDITO ORDINARIO
# 3364             0                              IBR CREDITO ORDINARIO
# 3365             0                           IBR TARJETA AGROPECUARIA
# 3366             0  1987 IBR MICROCREDITO GLOBAL POPULAR PRODUCTIV...
# 3367             0                           IBR TARJETA AGROPECUARIA
# 3368             0    1973 IBR MICROCREDITO POPULAR PRODUCTIVO URBANO
#
#       indicador_lec  valor_subsidio nuevo
# 3349              0               0     0
# 3350              0               0     0
# 3351              0               0     0
# 3352              0               0     0
# 3353              0               0     0
# 3354              0               0     0
# 3355              0               0     0
# 3356              0               0     1
# 3357              0               0     0
# 3358              0               0     0
# 3359              0               0     0
# 3360              0               0     0
# 3361              0               0     0
# 3362              0               0     0
# 3363              0               0     0
# 3364              0               0     0
# 3365              0               0     0
# 3366              0               0     0
# 3367              0               0     0
# 3368              0               0     0
#
# [20 rows x 27 columns]

# %% [markdown]
#  Identifica cuántos registros hay por cada categoría

# %%
df['tipo_cartera']
# Out:
# 0       Redescuento
# 1       Redescuento
# 2       Redescuento
# 3       Redescuento
# 4       Redescuento
#            ...
# 3364    Redescuento
# 3365    Sustitutiva
# 3366    Redescuento
# 3367    Sustitutiva
# 3368    Sustitutiva
# Name: tipo_cartera, Length: 3369, dtype: object

# %%
df['tipo_cartera'].describe()
# Out:
# count            3369
# unique              3
# top       Redescuento
# freq             2946
# Name: tipo_cartera, dtype: object

# %%
df.value_counts('tipo_cartera')
# Out:
# tipo_cartera
# Redescuento     2946
# Sustitutiva      417
# Agropecuaria       6
# Name: count, dtype: int64

# %%
df['tipo_cartera'].unique()
# Out:
# array(['Redescuento', 'Sustitutiva', 'Agropecuaria'], dtype=object)

# %% [markdown]
# cuántos valores distintos de cero hay en esas columnas

# %%
print(df[['indicador_lec', 'valor_subsidio', 'nuevo']].nunique())
# Out:
# indicador_lec       2
# valor_subsidio    636
# nuevo               2
# dtype: int64

# %% [markdown]
# #3)eliminacion y 4)normalizacion

# %% [markdown]
# Limpiar valores numéricos (quitar comas y convertir a float)

# %%
cols_moneda = ['valor_credito', 'valor_inversion', 'valor_subsidio']
for col in cols_moneda:
    df[col] = df[col].replace({',': ''}, regex=True).astype(float)

# %% [markdown]
#  Convertir fecha a formato estándar AAAA-MM-DD

# %%
df['fecha_credito'] = pd.to_datetime(df['fecha_credito'])
# Out:
# /tmp/ipykernel_9253/1070932538.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['fecha_credito'] = pd.to_datetime(df['fecha_credito'])

# %% [markdown]
# Estandarizar textos (quitar espacios extra y pasar a mayúsculas iniciales)

# %%
df['sexo'] = df['sexo'].str.strip().str.capitalize()

# %% [markdown]
# Definir las columnas a eliminar

# %%
columnas_a_borrar = ['indicador_lec', 'valor_subsidio', 'nuevo','cod_municipio']

# %% [markdown]
# ELIMINAR columnas sin información (constantes o en cero)

# %%
df = df.drop(columns=columnas_a_borrar)

print("Columnas eliminadas. Ahora el dataset es más limpio.")
# Out:
# Columnas eliminadas. Ahora el dataset es más limpio.

# %% [markdown]
# como quedaron los datos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3369 entries, 0 to 3368
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id_credito                    3369 non-null   object
#  1   fecha_credito                 3369 non-null   datetime64[ns]
#  2   tipo_cartera                  3369 non-null   object
#  3   tipo_intermediario            3369 non-null   object
#  4   tipo_productor                3369 non-null   object
#  5   tipo_beneficiario             3369 non-null   object
#  6   tipo_persona                  3369 non-null   object
#  7   sexo                          3309 non-null   object
#  8   cod_destino                   3369 non-null   object
#  9   linea_credito                 3369 non-null   object
#  10  cadena                        3369 non-null   object
#  11  eslabon_cadena                3369 non-null   object
#  12  valor_credito                 3369 non-null   float64
#  13  valor_inversion               3369 non-null   float64
#  14  plazo                         3369 non-null   int64
#  15  periodo_gracia                3369 non-null   int64
#  16  cuotas                        3369 non-null   int64
#  17  cuotas_capital                3369 non-null   int64
#  18  tasa_indexacion               3369 non-null   object
#  19  periodicidad_tasa_indexacion  3050 non-null   object
#  20  puntos_adicionales            3369 non-null   float64
#  21  garantia_fag                  3369 non-null   int64
#  22  nombre_programa               3369 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(5), object(14)
# memory usage: 605.5+ KB

# %%
df.shape
# Out:
# (3369, 23)

# %%
df.columns
# Out:
# Index(['id_credito', 'fecha_credito', 'tipo_cartera', 'tipo_intermediario',
#        'tipo_productor', 'tipo_beneficiario', 'tipo_persona', 'sexo',
#        'cod_destino', 'linea_credito', 'cadena', 'eslabon_cadena',
#        'valor_credito', 'valor_inversion', 'plazo', 'periodo_gracia', 'cuotas',
#        'cuotas_capital', 'tasa_indexacion', 'periodicidad_tasa_indexacion',
#        'puntos_adicionales', 'garantia_fag', 'nombre_programa'],
#       dtype='object')

# %% [markdown]
# #Normalización.  transformar una "tabla plana" (donde todo está amontonado y repetido) en un Modelo en Estrella

# %% [markdown]
# Creación de "Dimensiones" (Tablas Maestras)

# %%
dim_productor = df[['tipo_productor', 'tipo_beneficiario', 'tipo_persona']].drop_duplicates().reset_index(drop=True)
dim_productor['id_productor'] = dim_productor.index + 1

# %% [markdown]
# El Mapeo (Conectar las tablas)

# %%
dim_destino = df[['cod_destino', 'linea_credito', 'cadena', 'eslabon_cadena']].drop_duplicates().reset_index(drop=True)
dim_destino['id_destino_meta'] = dim_destino.index + 1

# %%
df = df.merge(dim_productor, on=['tipo_productor', 'tipo_beneficiario', 'tipo_persona'])
df = df.merge(dim_destino, on=['cod_destino', 'linea_credito', 'cadena', 'eslabon_cadena'])

# %% [markdown]
# Creación de la "Tabla de Hechos" (Fact Table)

# %%
fact_desembolsos = df[[
    'id_credito', 'fecha_credito', 'id_productor', 'id_destino_meta',
    'sexo', 'valor_credito', 'valor_inversion', 'plazo', 'cuotas'
]]

# %% [markdown]
# histo

# %%
dim_productor.to_csv('dim_productor.csv', index=False)
dim_destino.to_csv('dim_destino.csv', index=False)
fact_desembolsos.to_csv('fact_desembolsos_limpio.csv', index=False)

print("Normalización completada exitosamente.")
# Out:
# Normalización completada exitosamente.

# %% [markdown]
# histograma

# %%
# Configurar el estilo para que se vea moderno en la infografía
plt.figure(figsize=(12, 7))
sns.set_style("whitegrid")

# Crear el histograma
# bins=15 crea 15 barras; puedes ajustar este número según veas los datos
ax = sns.histplot(df['valor_credito'], bins=15, color='#2E7D32', edgecolor='white', alpha=0.8)

# Personalización de títulos
plt.title('¿De cuánto son los créditos en Guática?', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Monto del Crédito (Pesos)', fontsize=12)
plt.ylabel('Número de Personas/Créditos', fontsize=12)

# Formatear el eje X para que los números tengan puntos de mil (5.000.000 en lugar de 5000000)
import matplotlib.ticker as ticker
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

# Eliminar bordes innecesarios para un look más limpio
sns.despine()

plt.show()

# %%
# Configurar el estilo visual
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

# Crear el histograma del valor del crédito
# bins=20 divide los montos en 20 grupos para ver mejor la forma
ax = sns.histplot(df['valor_credito'], bins=20, kde=True, color='forestgreen')

# Personalización para la infografía
plt.title('Distribución de Montos de Crédito en Guática', fontsize=15)
plt.xlabel('Valor del Crédito (Pesos)', fontsize=12)
plt.ylabel('Cantidad de Créditos', fontsize=12)

# Ajustar formato de moneda en el eje X
import matplotlib.ticker as ticker
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

plt.show()
